# %%
import pandas as pd
from pandas.tools.plotting import scatter_matrix
import numpy as np
import os
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

# %%
#read CSV to dataframe and ensure data types
county_df = pd.read_csv('county_aggregates.csv', dtype={'state':'str', 'county':'str'})
county_df['fips'] = county_df.state + county_df.county
#FIXME import tract to CBSA file to get valid geographies
#FIXME group all XXNA to the state level and drop them from county level -- mark FIPS as NA

# %%
county_2004_df = pd.read_csv('county_aggregates_post_2004.csv')

# %%
county_df.tail()
# Out:
#       Unnamed: 0  year state county  loan_average  income_average  \
# 3263        3263  2014    35    045        141.76           86.14
# 3264        3264  2014    18    141        124.91           86.98
# 3265        3265  2014    40    001         92.31           61.94
# 3266        3266  2014    29    021        104.07           77.21
# 3267        3267  2014    48    491        194.24          115.24
#
#       count_of_apps  app_volume   fips
# 3263           2013      285365  35045
# 3264           4462      557346  18141
# 3265            194       17909  40001
# 3266           1577      164124  29021
# 3267          18701     3632536  48491

# %%
#xticks = [0, 20, 40, 60, 80, 100, 120, 140, 160, 180, 200, 220, 240, 260, 280, 300, 320, 340, 360, 400]
#ax = county_df.loan_average.hist(bins=100)#
county_df.hist(figsize=(8,8), bins=100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10f7f7190>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1118e1fd0>]], dtype=object)

# %%
#county_df.plot(kind='hist', y='count_of_apps', bins=100)
#county_df.income_average.hist(bins=100)
#county_df.app_volume.hist(bins=100, by='year')
#county_df.app_volume.plot(kind='box')
pd.tools.plotting.scatter_matrix(county_df, figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x140053910>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1411f2dd0>]], dtype=object)

# %%
#for each county, make a list of years in which it has data
county_years = {}
for county in set(county_df.fips.ravel()):
    single_county = county_df[county_df.fips == county].copy()
    
    county_years[county] = list(single_county.year.ravel())
    
print county_years
# Out:
# {nan: [], '16079': [2014], '16073': [2014], '16071': [2014], '16077': [2014], '16075': [2014], '06115': [2014], '06111': [2014], '06113': [2014], '13023': [2014], '46111': [2014], '40145': [2014], '02100': [2014], '02105': [2014], '01085': [2014], '19159': [2014], '39109': [2014], '51065': [2014], '39105': [2014], '51067': [2014], '39107': [2014], '19151': [2014], '39101': [2014], '51063': [2014], '39103': [2014], '40029': [2014], '01081': [2014], '22009': [2014], '40027': [2014], '17013': [2014], '22001': [2014], '22003': [2014], '22005': [2014], '01123': [2014], '22007': [2014], '06029': [2014], '47123': [2014], '06021': [2014], '01125': [2014], '06023': [2014], '06025': [2014], '06027': [2014], '27173': [2014], '27171': [2014], '51600': [2014], '56017': [2014], '19171': [2014], '21101': [2014], '21103': [2014], '21105': [2014], '21107': [2014], '21109': [2014], '32013': [2014], '32011': [2014], '51840': [2014], '32017': [2014], '32015': [2014], '32019': [2014], '26157': [2014], '4
# ...
